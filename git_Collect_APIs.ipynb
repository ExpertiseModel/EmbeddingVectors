# %%
import pydriller as pyd
import pandas as pd
from datetime import datetime
import ast
import tokenize
import numpy as np

# %%
tf_source = pd.DataFrame(columns=['commit_ID', 'filename' ,'Author', 'Authored_Date','email','msg','Commiter','committer_date', 
                                   'project_path','project_name','Commit_before', 'Commit_after',
                                  'diff','diff_parsed'])

# %%
#tf_dt1 = datetime(2017,1, 1)
#tf_dt2 = datetime(2017, 12, 30)
#tf_bug = pd.DataFrame(columns=['commit_ID', 'Author','Authored_Date','email','msg', 'Commiter','committer_date',
                              # 'project_path','Commit_before', 'Commit_after','diff','Added_LOC','Removed_LOC',
                              # 'Num_LOC','token_counts'])
#path = []


#Authors = ['Valdo']

# %%
url_author = pd.read_csv(r'C:\GH-Dataset\Git_dt_roles\repo_url.csv')

# %%
url_author['repo_url_ch'] = url_author['repo_url']+'.git'

# %%
url_author['repo_url_ch'][0]
# Out:
# 'https://github.com/behnammodi/aidJS.git'

# %%
Corpus_notNA=url_author[-url_author['Name'].isna()]

# %%
merged_dt=Corpus_notNA.groupby(['u_id','Name'])['repo_url_ch'].apply(list).reset_index()

# %%
merged_dt['repo_url_ch'][91]
# Out:
# ['https://github.com/DIS-SIN/12-Days-of-Data.git',
#  'https://github.com/DIS-SIN/9-Days-of-Working-Remotely.git',
#  'https://github.com/Jordan-Morrison/bootstrap-site.git',
#  'https://github.com/DIS-SIN/Busrides.git',
#  'https://github.com/Jordan-Morrison/colours.git',
#  'https://github.com/DIS-SIN/Data-Literacy-Assessment.git',
#  'https://github.com/DIS-SIN/DOL-MVP.git',
#  'https://github.com/Jordan-Morrison/firstProject.git',
#  'https://github.com/Jordan-Morrison/fonts.git',
#  'https://github.com/Jordan-Morrison/GC-Tortilla.git',
#  'https://github.com/Jordan-Morrison/Ghost-Blog-App.git',
#  'https://github.com/Jordan-Morrison/Ghost-CMS-Test.git',
#  'https://github.com/Jordan-Morrison/Giftr.git',
#  'https://github.com/Jordan-Morrison/Jordan-Morrison.Github.io.git',
#  'https://github.com/Jordan-Morrison/js-namespace.git',
#  'https://github.com/Jordan-Morrison/localStorage-Contacts.git',
#  'https://github.com/Jordan-Morrison/Movie-Recommendations.git',
# ...

# %%
for row in range(22,100):
    path= merged_dt['repo_url_ch'][row]
    Author = merged_dt['Name'][row]
    i=0
    try:
        for commit in pyd.RepositoryMining(path_to_repo=path,only_authors=Author).traverse_commits():
            for modified_file in commit.modifications:
                if modified_file.filename.endswith(exts) and not modified_file.filename.endswith(not_exts):
                    tf_source = tf_source.append({'commit_ID': commit.hash,'filename':modified_file.filename, 'Author': commit.author.name, 
                                                  'Authored_Date':commit.author_date , 'email': commit.author.email,
                                                  'msg': commit.msg,'Commiter': commit.committer.name, 'committer_date': commit.committer_date,
                                                  'project_path':commit.project_path,'project_name':commit.project_name,
                                                  'Commit_before': modified_file.source_code_before,'Commit_after': modified_file.source_code,
                                                  'diff':modified_file.diff, 'diff_parsed':modified_file.diff_parsed}, ignore_index=True)
                
    except:
        i= i+1
# Out:
# Exception ignored in: <finalize object at 0x2898edff930; dead>
# Traceback (most recent call last):
#   File "C:\Users\morad\Anaconda3\lib\weakref.py", line 572, in __call__
#     return info.func(*info.args, **(info.kwargs or {}))
#   File "C:\Users\morad\Anaconda3\lib\tempfile.py", line 795, in _cleanup
#     _shutil.rmtree(name)
#   File "C:\Users\morad\Anaconda3\lib\shutil.py", line 516, in rmtree
#     return _rmtree_unsafe(path, onerror)
#   File "C:\Users\morad\Anaconda3\lib\shutil.py", line 395, in _rmtree_unsafe
#     _rmtree_unsafe(fullname, onerror)
#   File "C:\Users\morad\Anaconda3\lib\shutil.py", line 395, in _rmtree_unsafe
#     _rmtree_unsafe(fullname, onerror)
#   File "C:\Users\morad\Anaconda3\lib\shutil.py", line 395, in _rmtree_unsafe
#     _rmtree_unsafe(fullname, onerror)
#   [Previous line repeated 1 more time]
#   File "C:\Users\morad\Anaconda3\lib\shutil.py", line 400, in _rmtree_unsafe
#     onerror(os.unlink, fullname, sys.exc_info())
# ...

# %%
tf_source.to_csv(r'C:\GH-Dataset\Git_dt_roles\commits_dt_1.csv', index=None, header=True)

# %%
#final_dt=tf_source

# %%
tf_source
# Out:
#                                     commit_ID                       filename  \
# 0    1e8d41f1425f2ec63e9d280b132c09f68eca8dca            ProjectLuther.ipynb
# 1    a6ace5371e135813732d818e9a63d4ec3c49ed81            ProjectLuther.ipynb
# 2    f98052acafe148592115e0a91cc48fb86ff598a7            ProjectLuther.ipynb
# 3    45af1bf718a697a6653df9e5c1950389bd442cdc                     .gitignore
# 4    d6222b0d3ab4232c19653ec47cb22d0eef559281  A math of the integer list.py
# ..                                        ...                            ...
# 327  71ab4880597570445ed609467f58ecfd09d1fad9               viewseva.aspx.cs
# 328  71ab4880597570445ed609467f58ecfd09d1fad9                    volreg.aspx
# 329  71ab4880597570445ed609467f58ecfd09d1fad9                 volreg.aspx.cs
# 330  71ab4880597570445ed609467f58ecfd09d1fad9                  writejat.aspx
# 331  71ab4880597570445ed609467f58ecfd09d1fad9               writejat.aspx.cs
#
# ...

# %%
bk=tf_source[['commit_ID', 'filename' ,'Author', 'Authored_Date','email','msg','Commiter','committer_date','project_name','Commit_before', 'Commit_after']]

# %%
paths=merged_dt['repo_url_ch'][20]

# %%
paths
# Out:
# ['https://github.com/Chyngyz/21habits.git',
#  'https://github.com/Chyngyz/angular-animated-bb-8.git',
#  'https://github.com/Chyngyz/angular-webpack-starter.git',
#  'https://github.com/Chyngyz/angular1.5-meetup.git',
#  'https://github.com/Chyngyz/awesome-angular-components.git',
#  'https://github.com/Chyngyz/bcarousel.git',
#  'https://github.com/Chyngyz/be-email.git',
#  'https://github.com/Chyngyz/bmw.git',
#  'https://github.com/Chyngyz/bmw-newsletter.git',
#  'https://github.com/Chyngyz/BootsElem.git',
#  'https://github.com/Chyngyz/bravo.git',
#  'https://github.com/Chyngyz/call-reminder.git',
#  'https://github.com/Chyngyz/camex.git',
#  'https://github.com/Chyngyz/chngz.me.git',
#  'https://github.com/barryclark/jekyll-now.git',
#  'https://github.com/kylestetz/CLNDR.git',
#  'https://github.com/chec/commercejs-nextjs-demo-store.git',
#  'https://github.com/Chyngyz/dizi.git',
#  'https://github.com/Chyngyz/garage48-hackaton-frontend.git',
# ...

# %%
Author=[merged_dt['u_id'][20],merged_dt['Name'][20],merged_dt['u_id'][20].lower()]

# %%
Author
# Out:
# ['Chyngyz', 'Chyngyz Arystan uulu', 'chyngyz']

# %%
#, only_authors=Authors , since=tf_dt1, to=tf_dt2,path_to_repo=path, 
i=0
try:
    for path in paths:
        for commit in pyd.RepositoryMining(path_to_repo=path,only_authors=Author).traverse_commits():
            for modified_file in commit.modifications:
                if modified_file.filename.endswith(exts) and not modified_file.filename.endswith(not_exts):
                    tf_source = tf_source.append({'commit_ID': commit.hash,'filename':modified_file.filename, 'Author': commit.author.name, 
                                              'Authored_Date':commit.author_date , 'email': commit.author.email,
                                              'msg': commit.msg,'Commiter': commit.committer.name, 'committer_date': commit.committer_date,
                                              'project_path':commit.project_path,'project_name':commit.project_name,
                                              'Commit_before': modified_file.source_code_before,'Commit_after': modified_file.source_code,
                                              'diff':modified_file.diff, 'diff_parsed':modified_file.diff_parsed, 
                                              'methods':modified_file.methods, 'methods_before':modified_file.methods_before,
                                              'changed_method':modified_file.changed_methods,
                                              'Added_LOC':modified_file.added,'Removed_LOC':modified_file.removed,
                                              'Num_LOC':modified_file.nloc,'token_counts':modified_file.token_count}, ignore_index=True)
                
except:
    i= i+1

# %%
tf_source.to_csv(r'C:\GH-Dataset\Git_dt_roles\Chyngyz20.csv', index=None, header=True)

# %%
tf_source=pd.read_csv('C:\GH-Dataset\Git_dt_roles\Chyngyz20.csv')

# %%
bk=tf_source[94:].reset_index()

# %%
tf_source=bk.drop(['index'],axis=1)

# %%
import yaml
from os.path import realpath, dirname, basename, splitext, join
from collections import defaultdict
import os

# %%
#this is path of .yaml file
lang_dir=r"C:\GH-Dataset\users_ver2\gitlinguist"

# %%
#this function load the .yml file
def read_yml(dir):
    languages_path = join(lang_dir, "languages.yml")
    LANGUAGES = yaml.load(open(languages_path))
    return LANGUAGES

# %%
languages = read_yml(lang_dir)
# Out:
# C:\Users\morad\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   after removing the cwd from sys.path.

# %%
def git_linguist(LANGUAGES):
    dict_index = defaultdict(list)
    all_extension = []
    all_languages = []
    for name, options in sorted(LANGUAGES.items(), key=lambda k: k[0]):
        language = (dict(name=name,
                         color=options.get('color'),
                         type=options.get('type'),
                         aliases=options.get('aliases', []),
                         ace_mode=options.get('ace_mode'),
                         extensions=options.get('extensions', []),
                         filenames= options.get('filenames', [])))
        
        all_languages.append(name)
        
        extensions=sorted(options.get('extensions', []))
        for extension in extensions:
            if not extension.startswith('.'):
                raise ValueError("Extension is missing a '.': %s" % extension)
            dict_index[extension].append(language)
            if extension not in all_extension:
                all_extension.append(extension)
    return all_languages,all_extension,dict_index

# %%
#Here, we call the git_linguist function, to generate the datasets that we need for furthur steps
all_languages,all_extensions,extension_indexs=git_linguist(languages)

# %%
model_langs=['Python','Jupyter Notebook','Go', 'Java', 'Scala','Kotlin','Dart','C','C++','Objective-C','C#','Julia','Ruby','Perl','Rust','R']

# %%
model_extensions = []
for lang in model_langs:
    for item in languages[lang].get('extensions'):
        model_extensions.append(item)

# %%
len(model_extensions)
# Out:
# 94

# %%
#this a function that returns the list of programming languages related to an extension
def get_language(extention,extension_indexs):
    pro_lang={}
    pro_lang_lst=[]
    pro_lang=extension_indexs.get(extention)
    for item in pro_lang:
        pro_lang_lst.append(item.get('name'))
    return(pro_lang_lst)

# %%
def return_APIs(language,txt):
    API_list=[]
    if(language in {'Python','Jupyter Notebook','Go', 'Java', 'Scala','Kotlin','Dart'}):
        API_list=re.findall("(?:from|import)\s+\w*.+;*",txt)
    if(language in {'C','C++','Objective-C'}):
        API_list=re.findall("(?:include)\s+\w*.+,*",txt)
    if(language in {'C#','Julia'}):
        API_list=re.findall("(?:using)\s+\w*.+;*",txt)            
    if(language in {'Ruby','Perl'}):
        API_list=re.findall("(?:require)\s+\w*.+;*",txt)
    if(language in {'Rust','Perl'}):
        API_list=re.findall("(?:use|use crate::)\s+\w*.+;*",txt)
    if(language == 'R'):
        API_list=re.findall("(?:library)\s*\(*\s*\w*.+;*",txt)
        
    return API_list

# %%
all_langs={}
for index in file_extensions:
    if index in all_extensions:
        langs_lst = get_language(index,extension_indexs)
    for lng in langs_lst:
        if (lng not in all_langs):
            all_langs[lng] = index

# %%
all_langs
# Out:
# {'YAML': '.yml',
#  'Shell': '.sh',
#  'HAProxy': '.cfg',
#  'INI': '.cfg',
#  'GCC Machine Description': '.md',
#  'Markdown': '.md',
#  'JSON': '.json',
#  'JavaScript': '.js',
#  'Pug': '.jade',
#  'CSS': '.css',
#  'TSX': '.tsx',
#  'XML': '.tsx',
#  'Python': '.py',
#  'C': '.c',
#  'reStructuredText': '.rst',
#  'C++': '.h',
#  'Objective-C': '.h',
#  'Text': '.txt',
#  'Vim Help File': '.txt',
#  'PostScript': '.ps'}

# %%
tf_source = pd.read_csv(r'C:\GH-Dataset\Git_dt_roles\commits_dt_1.csv')

# %%
len(tf_source)
# Out:
# 33441

# %%
language_Contribution = pd.DataFrame(columns=['Name','email','project_name','langs','APIs'])

# %%
for i in range(0,len(tf_source)):
    Name= tf_source['Author'][i]
    email = tf_source['email'][i]
    project_name= tf_source['project_name'][i]
    filename, file_extension = os.path.splitext(tf_source['filename'][i])
    if file_extension in model_extensions:
        langs_lst = get_language(file_extension,extension_indexs)
    
        for lng in langs_lst:
            APIs=[]
            if(isinstance(tf_source['Commit_after'][i],str)):
                APIs=(return_APIs(lng,tf_source['Commit_after'][i]))
            elif(isinstance(tf_source['Commit_before'][i],str)):
                APIs=(return_APIs(lng,tf_source['Commit_before'][i]))
                
            language_Contribution= language_Contribution.append({'Name':Name,'email':email,'project_name':project_name,
                                                             'langs':lng,'APIs':APIs}
                                                         ,ignore_index=True)

# %%
if(isinstance(tf_source['Commit_after'][48],str)):
    print("yes")

# %%
type(tf_source['Commit_after'][48])
# Out:
# float

# %%
lng_contr_notna=language_Contribution[language_Contribution['APIs'].map(lambda d: len(d)) > 0].reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-9675c39865e8> in <module>
# ----> 1 lng_contr_notna=language_Contribution[language_Contribution['APIs'].map(lambda d: len(d)) > 0].reset_index()
#
# NameError: name 'language_Contribution' is not defined

# %%
lng_contr_notna=lng_contr_notna.drop('index',axis=1)

# %%
lng_contr_notna
# Out:
#                       Name                        email          project_name  \
# 0             Ben Campbell  benjaminjcampbell@fs.fed.us   Backpack.SqlBuilder
# 1             Ben Campbell  benjaminjcampbell@fs.fed.us   Backpack.SqlBuilder
# 2             Ben Campbell  benjaminjcampbell@fs.fed.us   Backpack.SqlBuilder
# 3             Ben Campbell  benjaminjcampbell@fs.fed.us   Backpack.SqlBuilder
# 4             Ben Campbell  benjaminjcampbell@fs.fed.us   Backpack.SqlBuilder
# ...                    ...                          ...                   ...
# 4908  Chyngyz Arystan uulu          camphosis@gmail.com  super-heroic-angular
# 4909  Chyngyz Arystan uulu          camphosis@gmail.com  super-heroic-angular
# 4910  Chyngyz Arystan uulu          camphosis@gmail.com  super-heroic-angular
# 4911  Chyngyz Arystan uulu          camphosis@gmail.com  super-heroic-angular
# 4912  Chyngyz Arystan uulu          camphosis@gmail.com  super-heroic-angular
#
# ...

# %%
import gensim
from gensim.parsing.preprocessing import *

# %%
#cleaning data based on steps define in custom_filter
def str_preprocessing(tokenize_sentence):
    CUSTOM_FILTERS = custom_filter()
    tokens_new = preprocess_string(" ".join(tokenize_sentence), CUSTOM_FILTERS)
    return tokens_new

# %%
#build a bundle of actions to clean data
def custom_filter():
    cstm_filter = [remove_stopwords]
    return cstm_filter

# %%
def split_sentence(corpus):
    sentences = [doc.split(" ") for doc in corpus]
    return sentences

# %%
def split_APIs(ls):
    snts = [re.split('( )|\/|<|>|;|,|\(|\)|\n|\r',doc) for doc in ls]
    return snts

# %%
#flat a list of lists into a list
def flatten_list(sentences):
    flatList = [ item for elem in sentences for item in elem]
    return flatList

# %%
flatt_API=[flatten_list(doc) for doc in sp_APIs]

# %%
#[re.split('( )|\/|<|>|;|,|\(|\)',doc) for doc in lng_contr_notna['APIs'][25]]

# %%
test=['import gensim\r','jinja2\r']

# %%
split_APIs(test)
# Out:
# [['import', ' ', 'gensim', None, ''], ['jinja2', None, '']]

# %%
sp_APIs=[split_APIs(doc) for doc in lng_contr_notna['APIs']]

# %%
lng_contr_notna['APIs'][25]
# Out:
# ['using Backpack.SqlBuilder.Sqlite;',
#  'using FluentAssertions;',
#  'using System.Data.Common;',
#  'using System.IO;',
#  'using Xunit.Abstractions;',
#  'using (var conn = DbProvider.CreateConnection())']

# %%
len(lng_contr_notna)
# Out:
# 4913

# %%
all_stopwords=STOPWORDS.union(set(['', ' ',None,'using','include','from','import','Import','From','require', 'use','crate','library','var','\n','new',
              'return','*',"'*'",'\r']))

# %%
clean_APIs=[]
for doc in flatt_API:
    clean_APIs.append([word for word in doc if not word in all_stopwords])

# %%
short_APIs=[]
for doc in clean_APIs:
    short_APIs.append([word for word in doc if  len(word)>2])

# %%
from gensim.models.doc2vec import Doc2Vec
import numpy, math

# %%
f='doc2vecR.200.30.20.5.1550908281.eAp.trained' # THE TRAINED DOC2VEC MODEL
mod = Doc2Vec.load (f)

# %%
#if word in w2v_model.wv.vocab:
model_APIs=[]
for doc in short_APIs:
    model_APIs.append([word for word in doc if word in mod.wv.vocab])

# %%
model_APIs
# Out:
# [['FluentAssertions',
#   'System.Collections.Generic',
#   'System.Data',
#   'Xunit',
#   'Xunit.Abstractions'],
#  ['System.Collections.Generic', 'Xunit', 'Xunit.Abstractions'],
#  ['FluentAssertions', 'System', 'System.Linq', 'Xunit', 'Xunit.Abstractions'],
#  ['FluentAssertions',
#   'System.Data.Common',
#   'System.IO',
#   'Xunit.Abstractions',
#   'conn'],
#  ['System.Collections.Generic', 'System.Linq', 'System.Reflection'],
#  ['System', 'System.Data', 'System.Text'],
#  ['System', 'System.Collections.Generic', 'System.Text'],
#  ['System.Data'],
#  ['System.Data'],
#  ['System', 'System.Data', 'System.Text'],
#  ['System'],
#  ['System.Collections.Generic'],
#  ['System.Reflection',
#   'System.Runtime.CompilerServices',
#   'System.Runtime.InteropServices'],
#  ['System', 'System.Collections.Generic', 'System.Linq', 'System.Text'],
#  ['System.Text'],
#  ['System.Text'],
#  ['System.Collections.Generic', 'System.Linq', 'System.Text'],
# ...

# %%
short_APIs
# Out:
# [['FluentAssertions',
#   'Backpack.SqlBuilder',
#   'System.Collections.Generic',
#   'System.Data',
#   'Xunit',
#   'Xunit.Abstractions'],
#  ['Backpack.SqlBuilder',
#   'Backpack.SqlBuilder.Test.Util',
#   'System.Collections.Generic',
#   'Xunit',
#   'Xunit.Abstractions'],
#  ['FluentAssertions',
#   'Backpack.SqlBuilder',
#   'System',
#   'System.Linq',
#   'Xunit',
#   'Xunit.Abstractions'],
#  ['FluentAssertions',
#   'Backpack.SqlBuilder.Dialects',
#   'System.Data.Common',
#   'System.IO',
#   'Xunit.Abstractions',
#   'conn',
#   'DbProvider.CreateConnection'],
#  ['System.Collections.Generic', 'System.Linq', 'System.Reflection'],
#  ['System', 'System.Data', 'System.Text'],
#  ['Backpack.SqlBuilder.Dialects',
#   'System',
#   'System.Collections.Generic',
#   'System.Text'],
#  ['System.Data'],
#  ['System.Data'],
#  ['System', 'System.Data', 'System.Text'],
#  ['System'],
#  ['System.Collections.Generic'],
#  ['System.Reflection',
# ...

# %%
flatt_API[0]
# Out:
# ['using',
#  ' ',
#  'FluentAssertions',
#  None,
#  '',
#  'using',
#  ' ',
#  'Backpack.SqlBuilder',
#  None,
#  '',
#  'using',
#  ' ',
#  'System.Collections.Generic',
#  None,
#  '',
#  'using',
#  ' ',
#  'System.Data',
#  None,
#  '',
#  'using',
#  ' ',
#  'Xunit',
#  None,
#  '',
#  'using',
#  ' ',
#  'Xunit.Abstractions',
#  None,
#  '']

# %%
#gensim.utils.simple_preprocess
processing_tokens = [gensim.utils.simple_preprocess(sen) for sen in lng_contr_notna['APIs']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-224-2923c758030f> in <module>
#       1 #gensim.utils.simple_preprocess
# ----> 2 processing_tokens = [gensim.utils.simple_preprocess(sen) for sen in lng_contr_notna['APIs']]
#
# <ipython-input-224-2923c758030f> in <listcomp>(.0)
#       1 #gensim.utils.simple_preprocess
# ----> 2 processing_tokens = [gensim.utils.simple_preprocess(sen) for sen in lng_contr_notna['APIs']]
#
# ~\Anaconda3\lib\site-packages\gensim\utils.py in simple_preprocess(doc, deacc, min_len, max_len)
#     312     """
#     313     tokens = [
# --> 314         token for token in tokenize(doc, lower=True, deacc=deacc, errors='ignore')
#     315         if min_len <= len(token) <= max_len and not token.startswith('_')
#     316     ]
#
# ...

# %%
#.jpg .png .pdg .gif .RData .dll .nupkg .pdn .abf .xlsx .csv .JPG .mdf .LDF .jpeg .mp3 .wma .pdb .otf .eot .svg .ttf
# .woff .woff2 .ico .swp .asset .list .asset .ser .deb .sig .db .PNG .map .LICENSE .zip ._' .mp4 .docx .svgz .1 .swf .o
#.umap
bk5=tf_source[tf_source['filename'].str.endswith(exts)]

# %%
bk4[bk4['filename'].str.endswith(".nunjucks")]
# Out:
#        index                                 commit_ID  \
# 43632  43760  322338cba66953845d6bd40153287da0d0225d84
# 43633  43761  322338cba66953845d6bd40153287da0d0225d84
# 43634  43762  322338cba66953845d6bd40153287da0d0225d84
# 43635  43763  322338cba66953845d6bd40153287da0d0225d84
# 43636  43764  322338cba66953845d6bd40153287da0d0225d84
# ...      ...                                       ...
# 44053  44181  3b3fd523ef5754b217d5436c177ea05305ea4eef
# 44057  44185  36b2d38f74f051feda38ac65c3ba6ac7a0d8bc37
# 44075  44203  54ec435badf34909b7ccb47a9ac8303fea58eb90
# 44298  44426  54ec435badf34909b7ccb47a9ac8303fea58eb90
# 44300  44428  7af11ba94914104572b1caef8c1a4e4269870f5e
#
#                        filename                Author  \
# 43632        countries.nunjucks  Chyngyz Arystan uulu
# 43633            index.nunjucks  Chyngyz Arystan uulu
# 43634  individual-tour.nunjucks  Chyngyz Arystan uulu
# 43635            login.nunjucks  Chyngyz Arystan uulu
# ...

# %%
tf_source=bk5.reset_index()

# %%
del_ext = ['.jpg',
'.png',
'.pdf',
'.gif',
'.RData',
'.dll',
'.nupkg',
'.pdn',
'.abf',
'.xlsx',
'.csv',
'.JPG',
'.mdf',
'.LDF',
'.jpeg',
'.mp3',
'.wma',
'.pdb',
'.otf',
'.eot',
'.svg',
'.ttf',
'.woff',
'.woff2',
'.ico',
'.swp',
'.asset',
'.list',
'.asset',
'.ser',
'.deb',
'.sig',
'.db',
'.PNG',
'.map',
'.LICENSE',
'.zip',
'._',
'.mp4',
'.docx',
'.svgz',
'0.1',
'.swf',
'.o',
'.umap',
'.exe',
'.xmta',
'.cruise',
'.webp',
'.node','.DS_Store','.pyc','.jar',
 '.ks',
 '.class',
 '.icns',
 '.der',
 '.wav',
 '.winmd',
 '.so',
 '.exp',
 '.sql',
 '.md',
 '.suo',
 '.cache',
 '.p7s',
 '.sln',
 '.chm',
 '.xcf',
 '.1',
 '.psd',
 '.cpt',
 '.bmp',
 '.uasset',
 '.unity',
 '.mat',
 '.fbx',
 '.prefab',
 '.physicMaterial',
 '.renderTexture',
 '.by',
 '.e',
 '.ec',
 '.f',
 '.fd',
 '.fil',
 '.fu',
 '.gv',
 '.icl',
 '.iu',
 '.ma',
 '.to',
 '.pcx',
 '.xls',
 '.WAV',
 '.au',
 '.auf',
 '.proj',
 '.doc',
 '.sib',
 '.mid',
 '.mp',
 '.iff',
 '.tif',
 '.gem',
 '.vsdx',
 '.~vsdx',
 '.pptx',
 '.gzip',
 '.webm',
 '.un~',
 '.txt',
 '.gz','.nunjucks','.watchr','.must+be-escaped','.as','.BSD','.tap','.pre','.post','.partial','.Makefile','.gyp','.org',
          '.aplha','.alpha','.gi$']

# %%
not_exts=tuple(del_ext)

# %%
file_name="test.org"

# %%
if file_name.endswith(exts) and not file_name.endswith(not_exts):
    print(file_name)

# %%
tf_source=tf_source.drop(['index'],axis=1)

# %%
tf_source=tf_source.reset_index()

# %%
#tf_source

# %%
tf_source=bk5.reset_index()

# %%
tf_source
# Out:
#                                       commit_ID  \
# 0      093319169c7a7c291c491c3847cb0e31bc09e884
# 1      093319169c7a7c291c491c3847cb0e31bc09e884
# 2      093319169c7a7c291c491c3847cb0e31bc09e884
# 3      093319169c7a7c291c491c3847cb0e31bc09e884
# 4      093319169c7a7c291c491c3847cb0e31bc09e884
# ...                                         ...
# 33436  a901c567d8b224acf06d4f050dd32af71c3bd028
# 33437  a901c567d8b224acf06d4f050dd32af71c3bd028
# 33438  a901c567d8b224acf06d4f050dd32af71c3bd028
# 33439  a901c567d8b224acf06d4f050dd32af71c3bd028
# 33440  a901c567d8b224acf06d4f050dd32af71c3bd028
#
#                               filename                Author  \
# 0                           .gitignore          Ben Campbell
# 1      Backpack.SqlBuilder.Test.csproj          Ben Campbell
# 2                   CreateTableTest.cs          Ben Campbell
# 3              SqlInsertCommandTest.cs          Ben Campbell
# 4              SqlSelectBuilderTest.cs          Ben Campbell
# ...

# %%
bk5=tf_source[-tf_source['diff'].str.contains("Binary files")]

# %%
test=tf_source[tf_source['diff'].str.contains("Binary files")].reset_index()

# %%
tf_source=bk3.reset_index()

# %%
#tf_source['Commit_after'][18631]

# %%
file_extensions=[]
for i in range(0,len(tf_source)):
    filename, file_extension = os.path.splitext(tf_source['filename'][i])
    file_extensions.append(file_extension)

# %%
file_extensions = list(dict.fromkeys(file_extensions))

# %%
tf_source[tf_source['filename'].str.endswith(".org")]
# Out:
#                                       commit_ID        filename  \
# 25112  d3549776f933c3630b0667b4cb17218165434fe6  server.key.org
# 29496  d3549776f933c3630b0667b4cb17218165434fe6      README.org
# 31225  e4e20385c8514de18781e3030513123779f5e72f  server.key.org
# 35609  e4e20385c8514de18781e3030513123779f5e72f      README.org
#
#                      Author              Authored_Date                email  \
# 25112  Chyngyz Arystan uulu  2015-11-20 21:54:19+06:00  camphosis@gmail.com
# 29496  Chyngyz Arystan uulu  2015-11-20 21:54:19+06:00  camphosis@gmail.com
# 31225  Chyngyz Arystan uulu  2015-11-20 23:17:26+06:00  camphosis@gmail.com
# 35609  Chyngyz Arystan uulu  2015-11-20 23:17:26+06:00  camphosis@gmail.com
#
#                     msg              Commiter             committer_date  \
# 25112       Almost done  Chyngyz Arystan uulu  2015-11-20 21:54:19+06:00
# 29496       Almost done  Chyngyz Arystan uulu  2015-11-20 21:54:19+06:00
# ...

# %%
new_not=[]
for name in file_extensions:
    if name not in all_extensions:
        new_not.append(name)

# %%
if('.' in all_extensions):
    print("Yes")
# Out:
# Yes

# %%
new_not=new_not[1:]

# %%
new_not_tp=tuple(new_not)

# %%
exts=tuple(all_extensions)

# %%
file_extensions
# Out:
# ['.yml',
#  '.sh',
#  '.sqlite3',
#  '.cfg',
#  '.md',
#  '.json',
#  '.js',
#  '.jade',
#  '.css',
#  '',
#  '.snap',
#  '.tsx',
#  '.py',
#  '.c',
#  '.rst',
#  '.h',
#  '.dist',
#  '.vcproj',
#  '.in',
#  '.txt',
#  '.pdf',
#  '.png',
#  '.ps',
#  '.conf',
#  '.ac']

# %%
test=tf_source[tf_source['filename'].str.contains(".json")].reset_index()

# %%
test=tf_source['Commit_after'][55]

# %%
text=test['Commit_after'][0]

# %%
test = " library(ggplot2)\n \nlibrary(tidyverse)"

# %%
import re

# %%
text
# Out:
# '{\n  "name": "ng-webpack-seed",\n  "version": "1.0.0",\n  "description": "Angular 1.5 Webpack seed with ES6 support ",\n  "main": "index.js",\n  "scripts": {\n    "serve": "node node_modules/.bin/webpack-dev-server --inline --progress --colors",\n    "build": "node node_modules/.bin/rimraf dist && NODE_ENV=production webpack -p --config webpack.prod.config.js --progress",\n    "serve:dist": "node node_modules/.bin/http-server ./dist -p 3000",\n    "start": "npm run serve"\n  },\n  "keywords": [\n    "angular",\n    "webpack",\n    "angular-webpack",\n    "es6"\n  ],\n  "author": "Chyngyz Arystan uulu",\n  "license": "ISC",\n  "devDependencies": {\n    "babel-core": "^6.7.6",\n    "babel-loader": "^6.2.4",\n    "babel-preset-es2015": "^6.6.0",\n    "copy-webpack-plugin": "^2.1.1",\n    "css-loader": "^0.23.1",\n    "extract-text-webpack-plugin": "^1.0.1",\n    "file-loader": "^0.8.5",\n    "html-webpack-plugin": "^2.16.0",\n    "http-server": "^0.9.0",\n    "ng-annotate-loader": "^0.
# ...

# %%
re.split("( )|:|@|\/|<|>|;|,|\(|\)|\n|\r|\[|\]|\{|\}",text)
# Out:
# ['',
#  None,
#  '',
#  None,
#  '',
#  ' ',
#  '',
#  ' ',
#  '"name"',
#  None,
#  '',
#  ' ',
#  '"ng-webpack-seed"',
#  None,
#  '',
#  None,
#  '',
#  ' ',
#  '',
#  ' ',
#  '"version"',
#  None,
#  '',
#  ' ',
#  '"1.0.0"',
#  None,
#  '',
#  None,
#  '',
#  ' ',
#  '',
#  ' ',
#  '"description"',
#  None,
#  '',
#  ' ',
#  '"Angular',
#  ' ',
#  '1.5',
#  ' ',
#  'Webpack',
#  ' ',
#  'seed',
#  ' ',
#  'with',
#  ' ',
#  'ES6',
#  ' ',
#  'support',
#  ' ',
#  '"',
#  None,
#  '',
#  None,
#  '',
#  ' ',
#  '',
#  ' ',
#  '"main"',
#  None,
#  '',
#  ' ',
#  '"index.js"',
#  None,
#  '',
#  None,
#  '',
#  ' ',
#  '',
#  ' ',
#  '"scripts"',
#  None,
#  '',
#  ' ',
#  '',
#  None,
#  '',
#  None,
#  '',
#  ' ',
#  '',
#  ' ',
#  '',
#  ' ',
#  '',
#  ' ',
#  '"serve"',
#  None,
#  '',
#  ' ',
#  '"node',
#  ' ',
#  'node_modules',
#  None,
#  '.bin',
#  None,
#  'webpack-dev-server',
#  ' ',
#  '--inline',
#  ' ',
#  '--progress',
#  ' ',
#  '--colors"',
#  None,
#  '',
# ...

# %%
re.findall("(?:library)\s*\(*\s*\w*.+;*",test)
# Out:
# ['library(ggplot2)', 'library(tidyverse)']

# %%
re.findall("(?:using)\s+\w*.+;*",test)
# Out:
# ['using System.Globalization; ', 'using System.Linq; ', 'using System.Text; ']

# %%
re.findall("\s*(?:from|import)\s+{*'*\s*(?:\.*\/*)*\s*(\w*\.*-*_*\w*(?:\s*,\s*{*'*\s*(?:\.*\/*)*\w*\.*-*_*\w*)*)", test)
# Out:
# ['sys, os, imp, re, optparse',
#  'glob',
#  'glob',
#  'sysconfig',
#  'distutils',
#  'log',
#  'distutils',
#  'text_file',
#  'distutils.errors',
#  '',
#  'distutils.core',
#  'Extension, setup',
#  'distutils.command',
#  'build_ext',
#  'distutils.command',
#  'install',
#  'distutils.command',
#  'install_lib',
#  'distutils.spawn',
#  'find_executable',
#  'check',
#  'check',
#  'check',
#  'check',
#  'the',
#  'raising',
#  'ncurses',
#  'the',
#  'this',
#  'this',
#  'os.path',
#  'join, exists',
#  'distutils.dep_util',
#  'newer_group',
#  'distutils.dir_util',
#  'mkpath',
#  'warnings']

# %%
len(re.findall('(?:from|import)\s+(\w+)', test))
# Out:
# 36

# %%
re.findall('(?:from|import)\s+(\w+(?:\s*,\s*\w+)*)', test)
# Out:
# ['sys, os, imp, re, optparse',
#  'glob',
#  'glob',
#  'sysconfig',
#  'distutils',
#  'log',
#  'distutils',
#  'text_file',
#  'distutils',
#  'distutils',
#  'Extension, setup',
#  'distutils',
#  'build_ext',
#  'distutils',
#  'install',
#  'distutils',
#  'install_lib',
#  'distutils',
#  'find_executable',
#  'check',
#  'check',
#  'check',
#  'check',
#  'the',
#  'raising',
#  'ncurses',
#  'the',
#  'this',
#  'this',
#  'os',
#  'join, exists',
#  'distutils',
#  'newer_group',
#  'distutils',
#  'mkpath',
#  'warnings']

# %%
tf_source.iloc[10]
# Out:
# commit_ID                  ce5377791e631193881c5aa67ed8acfb3101961c
# Author                                                Kyle Mitchell
# Authored_Date                             2015-07-28 19:49:12-07:00
# email                                           kyle@kemitchell.com
# msg                            add CC-BY-SA-4.0 license for content
# Commiter                                              Kyle Mitchell
# committer_date                            2015-07-28 19:55:49-07:00
# project_path      C:\Users\morad\AppData\Local\Temp\tmpl0_bwsi0\...
# project_name                                           freeCodeCamp
# Commit_before     Copyright (c) 2015 Free Code Camp . All rights...
# Commit_after      Copyright (c) 2015 Free Code Camp.\n\n# Comput...
# diff              @@ -1,10 +1,170 @@\n-Copyright (c) 2015 Free C...
# diff_parsed       {'added': [(1, 'Copyright (c) 2015 Free Code C...
# methods                                                          []
# ...

# %%
tf_source.to_csv(r'C:\GH-Dataset\Git_dt_roles\commits_dt.csv', index=None, header=True)
